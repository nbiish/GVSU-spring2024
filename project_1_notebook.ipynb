# %% [markdown]
# <a href="https://colab.research.google.com/github/nbiish/GVSU-spring2024/blob/main/project_1_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# calculates airfare based on INPUT for:
# day
# destination
# row #
# checked bags & optional Premium Plus

    #       IMPORTANT
    #     Planes have 35 rows
    #     First Class w higher fare
    #         Rows 1-7
    #     Preferred seating w additional fee
    #         Rows 8-13
    #         Rows 16-20
    #         Rows 14-15 <--exit rows

# City | Mon  | Tue  | Wed  | Thu  | Fri  | Sat  | Sun
#  --- | ---  | ---  | ---  | ---  | ---  | ---  | ---
#  DFW | $213 | $198 | $198 | $213 | $399 | $213 | $198
#  LAX | $334 | $314 | $314 | $334 | $429 | $334 | $314
#  MIA | $279 | $204 | $204 | $279 | $370 | $279 | $204
#  SEA | $315 | $294 | $294 | $315 | $430 | $315 | $294
#  BOS | $241 | $205 | $205 | $241 | $298 | $241 | $205

# %% [markdown]
# # [✅] Phase 1 Destination

# %%
##### Phase 1 Destination - TODO #####

# [✅] prompt for destination
#       [✅] LAX
# [✅] identify fare for monday
# [✅] calculate taxes at 18%
# [✅] calculate total price
# [✅] print summary
#     [✅] ticket price
#     [✅] fare
#     [✅] taxes
#     [✅] total
#
# [✅] zybooks test

day = 'MON'

print("---Enter Information---\n")
destination = input("Destination Options: DFW LAX MIA SEA BOS ").upper()

def fare_calculation(destination, day):
  fare = 0
  tax = 0
  total = 0
  summary = ''
  if destination == 'LAX' and day == 'MON':
    fare = 334
    tax = fare * 0.18
    total = fare + tax
    summary = f"\nTicket Price Summary\nFare: ${fare}\nTaxes: ${tax:.2f}\nTotal: ${total:.2f}"
  else:
    summary = f"\n'{destination}' is not an options currently.."
  return summary

print(fare_calculation(destination, day))
# Out:
# ---Enter Information---
#
# Destination Options: DFW LAX MIA SEA BOS lax
#
# Ticket Price Summary
# Fare: $334
# Taxes: $60.12
# Total: $394.12

# %% [markdown]
# # [✅] Phase 2 Destination and Day

# %%
##### TODO - Phase 2 Destination and Day #####
#
# [✅] prompt for destination
# [✅] prompt for day
#
# [] calculate each day/destination price
#     [✅] DFW function
#         [✅] if section
#
#     [✅] LAX function
#         [✅] elif section
#
#     [✅] MIA function
#         [✅] elif section
#
#     [✅] SEA function
#         [✅] elif section
#
#     [✅] BOS function
#         [] elif section
#
##############################################
# City | Mon  | Tue  | Wed  | Thu  | Fri  | Sat  | Sun
#  --- | ---  | ---  | ---  | ---  | ---  | ---  | ---
#  DFW | $213 | $198 | $198 | $213 | $399 | $213 | $198
#  LAX | $334 | $314 | $314 | $334 | $429 | $334 | $314
#  MIA | $279 | $204 | $204 | $279 | $370 | $279 | $204
#  SEA | $315 | $294 | $294 | $315 | $430 | $315 | $294
#  BOS | $241 | $205 | $205 | $241 | $298 | $241 | $205

print("---Enter Information---\n")
destination = input("Destination Options: DFW LAX MIA SEA BOS --> ").upper()
day = input("Day of week: MON TUE WED THU FRI SAT SUN --> ").upper()

#########################################################

#CALCULATES FARE BY DESTINATION & DAY
def fare_calculation(destination, day):
  fare = 0
  tax = 0
  total = 0
  summary = ''

  #DFW PRICING BY DAY
  def dfw_pricing(day):
    fare = 0
    if day == 'MON':
      fare = 213
    elif day == 'TUE':
      fare = 198
    elif day == 'WED':
      fare = 198
    elif day == 'THU':
      fare = 213
    elif day == 'FRI':
      fare = 399
    elif day == 'SAT':
      fare = 213
    elif day == 'SUN':
      fare = 198
    return fare

  #LAX PRICING BY DAY
  def lax_pricing(day):
    fare = 0
    if day == 'MON':
      fare = 334
    elif day == 'TUE':
      fare = 314
    elif day == 'WED':
      fare = 314
    elif day == 'THU':
      fare = 334
    elif day == 'FRI':
      fare = 429
    elif day == 'SAT':
      fare = 334
    elif day == 'SUN':
      fare = 314
    return fare

  #MIA PRICING BY DAY
  def mia_pricing(day):
    fare = 0
    if day == 'MON':
      fare = 279
    elif day == 'TUE':
      fare = 204
    elif day == 'WED':
      fare = 204
    elif day == 'THU':
      fare = 279
    elif day == 'FRI':
      fare = 370
    elif day == 'SAT':
      fare = 279
    elif day == 'SUN':
      fare = 204
    return fare

  #SEA PRICING BY DAY
  def sea_pricing(day):
    fare = 0
    if day == 'MON':
      fare = 315
    elif day == 'TUE':
      fare = 294
    elif day == 'WED':
      fare = 294
    elif day == 'THU':
      fare = 315
    elif day == 'FRI':
      fare = 430
    elif day == 'SAT':
      fare = 315
    elif day == 'SUN':
      fare = 294
    return fare

  #BOS PRICING BY DAY
  def bos_pricing(day):
    fare = 0
    if day == 'MON':
      fare = 241
    elif day == 'TUE':
      fare = 205
    elif day == 'WED':
      fare = 205
    elif day == 'THU':
      fare = 241
    elif day == 'FRI':
      fare = 298
    elif day == 'SAT':
      fare = 241
    elif day == 'SUN':
      fare = 205
    return fare

  #CHECK FOR DESTINATION --> USES FUNCTIONS ABOVE <--
  if destination == 'DFW':
    fare = dfw_pricing(day) #<-- DFW FUNCTION
    tax = fare * 0.18
    total = fare + tax
    summary = f"\nTicket Price Summary:\nFare: ${fare}\nTaxes: ${tax:.2f}\nTotal: ${total:.2f}"
  elif destination == 'LAX':
    fare = lax_pricing(day) #<-- LAX FUNCTION
    tax = fare * 0.18
    total = fare + tax
    summary = f"\nTicket Price Summary:\nFare: ${fare}\nTaxes: ${tax:.2f}\nTotal: ${total:.2f}"
  elif destination == 'MIA':
    fare = mia_pricing(day) #<-- MIA FUNCTION
    tax = fare * 0.18
    total = fare + tax
    summary = f"\nTicket Price Summary:\nFare: ${fare}\nTaxes: ${tax:.2f}\nTotal: ${total:.2f}"
  elif destination == 'SEA':
    fare = sea_pricing(day) #<-- SEA FUNCTION
    tax = fare * 0.18
    total = fare + tax
    summary = f"\nTicket Price Summary:\nFare: ${fare}\nTaxes: ${tax:.2f}\nTotal: ${total:.2f}"
  elif destination == 'BOS':
    fare = bos_pricing(day) #<-- BOS FUNCTION
    tax = fare * 0.18
    total = fare + tax
    summary = f"\nTicket Price Summary:\nFare: ${fare}\nTaxes: ${tax:.2f}\nTotal: ${total:.2f}"
  else:
     summary = f"\nYour input had an error, try something else."

  return summary

#######################################################
print(fare_calculation(destination, day))
# Out:
# ---Enter Information---
#
# Destination Options: DFW LAX MIA SEA BOS --> lax
# Day of week: MON TUE WED THU FRI SAT SUN --> tue
#
# Ticket Price Summary:
# Fare: $314
# Taxes: $56.52
# Total: $370.52

# %% [markdown]
# # [✅] Phase 3 First Class

# %%
##### TODO - Phase 3 First Class #####
#
# [✅] prompt for row number: 1-7 for first class --> fare *= 0.75
# [✅] calculate new option
# [✅] print "First Class: {first_class_yes_no} adds ${first_class_charge}"
# [✅] new summary

print("---Enter Information---\n")
destination = input("Destination Options: DFW LAX MIA SEA BOS --> ").upper()
day = input("Day of week: MON TUE WED THU FRI SAT SUN --> ").upper()
print("\nDesired Seating:\nFirst Class (Rows 1-7) + 75%")
row = int(float(input("Desired Row Number: ")))

#########################################################

#CALCULATES FARE BY DESTINATION & DAY
def fare_calculation(destination, day, row):

  #MAIN FUNCTION VARIABLES
  fare = 0
  subtotal = 0
  tax = 0
  total = 0
  summary = ''

  #DETERMINE FIRST CLASS
  first_class_charge = 0
  first_class_yes_no = 'NO'
  first_class = False
  if 8>row>0:
    first_class = True
    first_class_yes_no = 'YES'

  #DFW PRICING BY DAY
  def dfw_pricing(day):
    fare = 0
    if day == 'MON':
      fare = 213
    elif day == 'TUE':
      fare = 198
    elif day == 'WED':
      fare = 198
    elif day == 'THU':
      fare = 213
    elif day == 'FRI':
      fare = 399
    elif day == 'SAT':
      fare = 213
    elif day == 'SUN':
      fare = 198
    return fare

  #LAX PRICING BY DAY
  def lax_pricing(day):
    fare = 0
    if day == 'MON':
      fare = 334
    elif day == 'TUE':
      fare = 314
    elif day == 'WED':
      fare = 314
    elif day == 'THU':
      fare = 334
    elif day == 'FRI':
      fare = 429
    elif day == 'SAT':
      fare = 334
    elif day == 'SUN':
      fare = 314
    return fare

  #MIA PRICING BY DAY
  def mia_pricing(day):
    fare = 0
    if day == 'MON':
      fare = 279
    elif day == 'TUE':
      fare = 204
    elif day == 'WED':
      fare = 204
    elif day == 'THU':
      fare = 279
    elif day == 'FRI':
      fare = 370
    elif day == 'SAT':
      fare = 279
    elif day == 'SUN':
      fare = 204
    return fare

  #SEA PRICING BY DAY
  def sea_pricing(day):
    fare = 0
    if day == 'MON':
      fare = 315
    elif day == 'TUE':
      fare = 294
    elif day == 'WED':
      fare = 294
    elif day == 'THU':
      fare = 315
    elif day == 'FRI':
      fare = 430
    elif day == 'SAT':
      fare = 315
    elif day == 'SUN':
      fare = 294
    return fare

  #BOS PRICING BY DAY
  def bos_pricing(day):
    fare = 0
    if day == 'MON':
      fare = 241
    elif day == 'TUE':
      fare = 205
    elif day == 'WED':
      fare = 205
    elif day == 'THU':
      fare = 241
    elif day == 'FRI':
      fare = 298
    elif day == 'SAT':
      fare = 241
    elif day == 'SUN':
      fare = 205
    return fare

  #CHECK FOR DESTINATION & FIRST_CLASS --> USES FUNCTIONS ABOVE <--
  if destination == 'DFW':
    day_of_week_price = dfw_pricing(day) #<-- DFW FUNCTION
    #CHECK FIRST CLASS ###############
    if first_class:
      first_class_charge = day_of_week_price * 0.75
      subtotal = day_of_week_price + first_class_charge
    else:
      subtotal = day_of_week_price
    ##################################
    tax = subtotal * 0.18
    total = subtotal + tax
    summary = f"""\n{'*'*27}\nTICKET PRICE SUMMARY:\nTicket: ${day_of_week_price:.2f}\nFirst Class Option: {first_class_yes_no}\n-adds ${first_class_charge:.2f}\n\n{'*'*18}\nsubtotal: ${subtotal:.2f}\nTaxes: ${tax:.2f}\nTotal: ${total:.2f}\n{'*'*27}"""

  elif destination == 'LAX':
    day_of_week_price = lax_pricing(day) #<-- LAX FUNCTION
    #CHECK FIRST CLASS ###############
    if first_class:
      first_class_charge = day_of_week_price * 0.75
      subtotal = day_of_week_price + first_class_charge
    else:
      subtotal = day_of_week_price
    ##################################
    tax = subtotal * 0.18
    total = subtotal + tax
    summary = f"""\n{'*'*27}\nTICKET PRICE SUMMARY:\nTicket: ${day_of_week_price:.2f}\nFirst Class Option: {first_class_yes_no}\n-adds ${first_class_charge:.2f}\n\n{'*'*18}\nsubtotal: ${subtotal:.2f}\nTaxes: ${tax:.2f}\nTotal: ${total:.2f}\n{'*'*27}"""

  elif destination == 'MIA':
    day_of_week_price = mia_pricing(day) #<-- MIA FUNCTION
    #CHECK FIRST CLASS ###############
    if first_class:
      first_class_charge = day_of_week_price * 0.75
      subtotal = day_of_week_price + first_class_charge
    else:
      subtotal = day_of_week_price
    ##################################
    tax = subtotal * 0.18
    total = subtotal + tax
    summary = f"""\n{'*'*27}\nTICKET PRICE SUMMARY:\nTicket: ${day_of_week_price:.2f}\nFirst Class Option: {first_class_yes_no}\n-adds ${first_class_charge:.2f}\n\n{'*'*18}\nsubtotal: ${subtotal:.2f}\nTaxes: ${tax:.2f}\nTotal: ${total:.2f}\n{'*'*27}"""

  elif destination == 'SEA':
    day_of_week_price = sea_pricing(day) #<-- SEA FUNCTION
    #CHECK FIRST CLASS ###############
    if first_class:
      first_class_charge = day_of_week_price * 0.75
      subtotal = day_of_week_price + first_class_charge
    else:
      subtotal = day_of_week_price
    ##################################
    tax = subtotal * 0.18
    total = subtotal + tax
    summary = f"""\n{'*'*27}\nTICKET PRICE SUMMARY:\nTicket: ${day_of_week_price:.2f}\nFirst Class Option: {first_class_yes_no}\n-adds ${first_class_charge:.2f}\n\n{'*'*18}\nsubtotal: ${subtotal:.2f}\nTaxes: ${tax:.2f}\nTotal: ${total:.2f}\n{'*'*27}"""

  elif destination == 'BOS':
    day_of_week_price = bos_pricing(day) #<-- BOS FUNCTION
    #CHECK FIRST CLASS ###############
    if first_class:
      first_class_charge = day_of_week_price * 0.75
      subtotal = day_of_week_price + first_class_charge
    else:
      subtotal = day_of_week_price
    ##################################
    tax = subtotal * 0.18
    total = subtotal + tax
    summary = f"""\n{'*'*27}\nTICKET PRICE SUMMARY:\nTicket: ${day_of_week_price:.2f}\nFirst Class Option: {first_class_yes_no}\n-adds ${first_class_charge:.2f}\n\n{'*'*18}\nsubtotal: ${subtotal:.2f}\nTaxes: ${tax:.2f}\nTotal: ${total:.2f}\n{'*'*27}"""

  return summary

#######################################################
if (destination not in ['DFW', 'LAX', 'MIA', 'SEA', 'BOS']) or (day not in ['MON', 'TUE', 'WED', 'THU', 'FRI', 'SAT', 'SUN']):
  print("\nInput had error")
else:
  print(fare_calculation(destination, day, row))
# Out:
# ---Enter Information---
#
# Destination Options: DFW LAX MIA SEA BOS --> bos
# Day of week: MON TUE WED THU FRI SAT SUN --> mon
#
# Desired Seating:
# First Class (Rows 1-7) + 75%
# Desired Row Number: 4
#
# ***************************
# TICKET PRICE SUMMARY:
# Ticket: $241.00
# First Class Option: YES
# -adds $180.75
#
# ******************
# subtotal: $421.75
# Taxes: $75.91
# Total: $497.66
# ***************************

# %% [markdown]
# # [✅] Phase 4 Preferred Seating

# %%
##### TODO - Phase 4 Preferred Seating
#
# [✅] rows 14-15 + $49
# [✅] rows 8-13 + $35
# [✅] rows 16-20 + $35
#
#########################################################

#CALCULATES FARE BY DESTINATION & DAY
def fare_calculation(destination, day, row):

  #MAIN FUNCTION VARIABLES
  fare = 0
  subtotal = 0
  tax = 0
  total = 0
  summary = ''

  #DETERMINE FIRST CLASS
  first_class_charge = 0
  first_class_yes_no = 'NO'
  is_first_class = False
  if 8>row>0:
    is_first_class = True
    first_class_yes_no = 'YES'

  #DETERMINE ADDITIONAL CHARGES
  additional_charges = 0
  premium_seating_yes_no = 'NO'
  is_exit_row = False
  is_leg_room_row = False
  exit_row_charge = 49
  leg_room_charge = 35
  if 13<row<16:
    is_exit_row = True
    premium_seating_yes_no = 'YES'
  elif 7<row<14 or 15<row<21:
    is_leg_room_row = True
    premium_seating_yes_no = 'YES'


  #DFW PRICING BY DAY
  def dfw_pricing(day):
    fare = 0
    if day == 'MON':
      fare = 213
    elif day == 'TUE':
      fare = 198
    elif day == 'WED':
      fare = 198
    elif day == 'THU':
      fare = 213
    elif day == 'FRI':
      fare = 399
    elif day == 'SAT':
      fare = 213
    elif day == 'SUN':
      fare = 198
    return fare

  #LAX PRICING BY DAY
  def lax_pricing(day):
    fare = 0
    if day == 'MON':
      fare = 334
    elif day == 'TUE':
      fare = 314
    elif day == 'WED':
      fare = 314
    elif day == 'THU':
      fare = 334
    elif day == 'FRI':
      fare = 429
    elif day == 'SAT':
      fare = 334
    elif day == 'SUN':
      fare = 314
    return fare

  #MIA PRICING BY DAY
  def mia_pricing(day):
    fare = 0
    if day == 'MON':
      fare = 279
    elif day == 'TUE':
      fare = 204
    elif day == 'WED':
      fare = 204
    elif day == 'THU':
      fare = 279
    elif day == 'FRI':
      fare = 370
    elif day == 'SAT':
      fare = 279
    elif day == 'SUN':
      fare = 204
    return fare

  #SEA PRICING BY DAY
  def sea_pricing(day):
    fare = 0
    if day == 'MON':
      fare = 315
    elif day == 'TUE':
      fare = 294
    elif day == 'WED':
      fare = 294
    elif day == 'THU':
      fare = 315
    elif day == 'FRI':
      fare = 430
    elif day == 'SAT':
      fare = 315
    elif day == 'SUN':
      fare = 294
    return fare

  #BOS PRICING BY DAY
  def bos_pricing(day):
    fare = 0
    if day == 'MON':
      fare = 241
    elif day == 'TUE':
      fare = 205
    elif day == 'WED':
      fare = 205
    elif day == 'THU':
      fare = 241
    elif day == 'FRI':
      fare = 298
    elif day == 'SAT':
      fare = 241
    elif day == 'SUN':
      fare = 205
    return fare

  #CHECK FOR DESTINATION & FIRST_CLASS & ROW CHARGES --> USES FUNCTIONS ABOVE <--
#IF START
  if destination == 'DFW':
    day_of_week_price = dfw_pricing(day) #<-- DFW FUNCTION
    #CHECK FIRST CLASS###############
    if is_first_class:
      first_class_charge = day_of_week_price * 0.75
      subtotal = day_of_week_price + first_class_charge
    #################################
    #ADD ROW LOGIC###################
    elif is_leg_room_row:
      additional_charges = leg_room_charge
      subtotal = day_of_week_price + leg_room_charge
    elif is_exit_row:
      additional_charges = exit_row_charge
      subtotal = day_of_week_price + exit_row_charge
    else:
      additional_charges = additional_charges
      subtotal = day_of_week_price
    #################################
    tax = subtotal * 0.18
    total = subtotal + tax
    summary = f"""\n{'*'*27}\nTICKET PRICE SUMMARY:\n\n{'-'*27}\nTicket: ${day_of_week_price:.2f}\n{'-'*27}\nFirst Class Option: {first_class_yes_no}\n-adds ${first_class_charge:.2f}\n{'-'*27}\nPremium Row Charges: {premium_seating_yes_no}\n-adds ${additional_charges:.2f}\n\n{'*'*18}\nSubtotal: ${subtotal:.2f}\nTaxes: ${tax:.2f}\nTOTAL: ${total:.2f}\n{'*'*27}"""

#NEXT ELIF
  elif destination == 'LAX':
    day_of_week_price = lax_pricing(day) #<-- LAX FUNCTION
    #CHECK FIRST CLASS###############
    if is_first_class:
      first_class_charge = day_of_week_price * 0.75
      subtotal = day_of_week_price + first_class_charge
    #################################
    #ADD ROW LOGIC###################
    elif is_leg_room_row:
      additional_charges = leg_room_charge
      subtotal = day_of_week_price + leg_room_charge
    elif is_exit_row:
      additional_charges = exit_row_charge
      subtotal = day_of_week_price + exit_row_charge
    else:
      additional_charges = additional_charges
      subtotal = day_of_week_price
    #################################
    tax = subtotal * 0.18
    total = subtotal + tax
    summary = f"""\n{'*'*27}\nTICKET PRICE SUMMARY:\n\n{'-'*27}\nTicket: ${day_of_week_price:.2f}\n{'-'*27}\nFirst Class Option: {first_class_yes_no}\n-adds ${first_class_charge:.2f}\n{'-'*27}\nPremium Row Charges: {premium_seating_yes_no}\n-adds ${additional_charges:.2f}\n\n{'*'*18}\nSubtotal: ${subtotal:.2f}\nTaxes: ${tax:.2f}\nTOTAL: ${total:.2f}\n{'*'*27}"""

#NEXT ELIF
  elif destination == 'MIA':
    day_of_week_price = mia_pricing(day) #<-- MIA FUNCTION
    #CHECK FIRST CLASS###############
    if is_first_class:
      first_class_charge = day_of_week_price * 0.75
      subtotal = day_of_week_price + first_class_charge
    #################################
    #ADD ROW LOGIC###################
    elif is_leg_room_row:
      additional_charges = leg_room_charge
      subtotal = day_of_week_price + leg_room_charge
    elif is_exit_row:
      additional_charges = exit_row_charge
      subtotal = day_of_week_price + exit_row_charge
    else:
      additional_charges = additional_charges
      subtotal = day_of_week_price
    #################################
    tax = subtotal * 0.18
    total = subtotal + tax
    summary = f"""\n{'*'*27}\nTICKET PRICE SUMMARY:\n\n{'-'*27}\nTicket: ${day_of_week_price:.2f}\n{'-'*27}\nFirst Class Option: {first_class_yes_no}\n-adds ${first_class_charge:.2f}\n{'-'*27}\nPremium Row Charges: {premium_seating_yes_no}\n-adds ${additional_charges:.2f}\n\n{'*'*18}\nSubtotal: ${subtotal:.2f}\nTaxes: ${tax:.2f}\nTOTAL: ${total:.2f}\n{'*'*27}"""

#NEXT ELIF
  elif destination == 'SEA':
    day_of_week_price = sea_pricing(day) #<-- SEA FUNCTION
    #CHECK FIRST CLASS###############
    if is_first_class:
      first_class_charge = day_of_week_price * 0.75
      subtotal = day_of_week_price + first_class_charge
    #################################
    #ADD ROW LOGIC###################
    elif is_leg_room_row:
      additional_charges = leg_room_charge
      subtotal = day_of_week_price + leg_room_charge
    elif is_exit_row:
      additional_charges = exit_row_charge
      subtotal = day_of_week_price + exit_row_charge
    else:
      additional_charges = additional_charges
      subtotal = day_of_week_price
    #################################
    tax = subtotal * 0.18
    total = subtotal + tax
    summary = f"""\n{'*'*27}\nTICKET PRICE SUMMARY:\n\n{'-'*27}\nTicket: ${day_of_week_price:.2f}\n{'-'*27}\nFirst Class Option: {first_class_yes_no}\n-adds ${first_class_charge:.2f}\n{'-'*27}\nPremium Row Charges: {premium_seating_yes_no}\n-adds ${additional_charges:.2f}\n\n{'*'*18}\nSubtotal: ${subtotal:.2f}\nTaxes: ${tax:.2f}\nTOTAL: ${total:.2f}\n{'*'*27}"""

#FINAL ELIF
  elif destination == 'BOS':
    day_of_week_price = bos_pricing(day) #<-- BOS FUNCTION
    #CHECK FIRST CLASS###############
    if is_first_class:
      first_class_charge = day_of_week_price * 0.75
      subtotal = day_of_week_price + first_class_charge
    #################################
    #ADD ROW LOGIC###################
    elif is_leg_room_row:
      additional_charges = leg_room_charge
      subtotal = day_of_week_price + leg_room_charge
    elif is_exit_row:
      additional_charges = exit_row_charge
      subtotal = day_of_week_price + exit_row_charge
    else:
      additional_charges = additional_charges
      subtotal = day_of_week_price
    #################################
    tax = subtotal * 0.18
    total = subtotal + tax
    summary = f"""\n{'*'*27}\nTICKET PRICE SUMMARY:\n\n{'-'*27}\nTicket: ${day_of_week_price:.2f}\n{'-'*27}\nFirst Class Option: {first_class_yes_no}\n-adds ${first_class_charge:.2f}\n{'-'*27}\nPremium Row Charges: {premium_seating_yes_no}\n-adds ${additional_charges:.2f}\n\n{'*'*18}\nSubtotal: ${subtotal:.2f}\nTaxes: ${tax:.2f}\nTOTAL: ${total:.2f}\n{'*'*27}"""

#IF END

  return summary


#######################################################
print("---Enter Information---\n")
destination = input("Destination Options: DFW LAX MIA SEA BOS --> ").upper()
day = input("Day of week: MON TUE WED THU FRI SAT SUN --> ").upper()
print("\nDesired Seating:\nFirst Class (Rows 1-7) + 75%")
row = input("Desired Row Number: ")


if (destination not in ['DFW', 'LAX', 'MIA', 'SEA', 'BOS']) or (day not in ['MON', 'TUE', 'WED', 'THU', 'FRI', 'SAT', 'SUN']) or (not row.isdigit()):
  print("\nInput had error")
else:
  row = int(float(row))
  print(fare_calculation(destination, day, row))
# Out:
# ---Enter Information---
#
# Destination Options: DFW LAX MIA SEA BOS --> lax
# Day of week: MON TUE WED THU FRI SAT SUN --> sat
#
# Desired Seating:
# First Class (Rows 1-7) + 75%
# Desired Row Number: 13
#
# ***************************
# TICKET PRICE SUMMARY:
#
# ---------------------------
# Ticket: $334.00
# ---------------------------
# First Class Option: NO
# -adds $0.00
# ---------------------------
# Premium Row Charges: YES
# -adds $35.00
#
# ******************
# Subtotal: $369.00
# Taxes: $66.42
# TOTAL: $435.42
# ***************************

# %% [markdown]
# # [✅] Phase 5 Baggage Fees

# %%
##### TODO - Phase 5 Baggage Fees
#
# [✅] $35 first additional carry-on
# [✅] $25 each additional carry-on
# [✅] baggage fees ARE NOT taxed (add to total vs subtotal)
#
#########################################################

#CALCULATES COSTS BY
  #DESTINATION
  #DAY
  #ROW
  #BAGGAGE
def fare_calculation(destination, day, row, number_of_bags):

  #MAIN FUNCTION VARIABLES
  fare = 0
  subtotal = 0
  tax = 0
  total = 0
  summary = ''

  #DETERMINE FIRST CLASS
  first_class_charge = 0
  first_class_yes_no = 'NO'
  is_first_class = False
  if 8>row>0:
    is_first_class = True
    first_class_yes_no = 'YES'
  first_class_summary = ''

  #DETERMINE ADDITIONAL CHARGES
  additional_charges = 0
  premium_seating_yes_no = 'NO'
  is_exit_row = False
  is_leg_room_row = False
  exit_row_charge = 49
  leg_room_charge = 35
  if 13<row<16:
    is_exit_row = True
    premium_seating_yes_no = 'YES'
  elif 7<row<14 or 15<row<21:
    is_leg_room_row = True
    premium_seating_yes_no = 'YES'
  premium_charge_summary = ''

  #DETERMINE BAGGAGE COSTS
  def baggage_pricing(number_of_bags):
    baggage_cost = 0
    if number_of_bags == 1:
      baggage_cost = 35
    elif number_of_bags > 1:
      baggage_cost = (((number_of_bags-1) * 25) +35)
    return baggage_cost
  baggage_summary = ''

  #DFW PRICING BY DAY
  def dfw_pricing(day):
    fare = 0
    if day == 'MON':
      fare = 213
    elif day == 'TUE':
      fare = 198
    elif day == 'WED':
      fare = 198
    elif day == 'THU':
      fare = 213
    elif day == 'FRI':
      fare = 399
    elif day == 'SAT':
      fare = 213
    elif day == 'SUN':
      fare = 198
    return fare

  #LAX PRICING BY DAY
  def lax_pricing(day):
    fare = 0
    if day == 'MON':
      fare = 334
    elif day == 'TUE':
      fare = 314
    elif day == 'WED':
      fare = 314
    elif day == 'THU':
      fare = 334
    elif day == 'FRI':
      fare = 429
    elif day == 'SAT':
      fare = 334
    elif day == 'SUN':
      fare = 314
    return fare

  #MIA PRICING BY DAY
  def mia_pricing(day):
    fare = 0
    if day == 'MON':
      fare = 279
    elif day == 'TUE':
      fare = 204
    elif day == 'WED':
      fare = 204
    elif day == 'THU':
      fare = 279
    elif day == 'FRI':
      fare = 370
    elif day == 'SAT':
      fare = 279
    elif day == 'SUN':
      fare = 204
    return fare

  #SEA PRICING BY DAY
  def sea_pricing(day):
    fare = 0
    if day == 'MON':
      fare = 315
    elif day == 'TUE':
      fare = 294
    elif day == 'WED':
      fare = 294
    elif day == 'THU':
      fare = 315
    elif day == 'FRI':
      fare = 430
    elif day == 'SAT':
      fare = 315
    elif day == 'SUN':
      fare = 294
    return fare

  #BOS PRICING BY DAY
  def bos_pricing(day):
    fare = 0
    if day == 'MON':
      fare = 241
    elif day == 'TUE':
      fare = 205
    elif day == 'WED':
      fare = 205
    elif day == 'THU':
      fare = 241
    elif day == 'FRI':
      fare = 298
    elif day == 'SAT':
      fare = 241
    elif day == 'SUN':
      fare = 205
    return fare

  #CHECK FOR DESTINATION & FIRST_CLASS & ROW CHARGES --> USES FUNCTIONS ABOVE <--
#START IF
  if destination == 'DFW':
    day_of_week_price = dfw_pricing(day) #<-- DFW FUNCTION
    #CHECK FIRST CLASS###############
    if is_first_class:
      first_class_charge = day_of_week_price * 0.75
      subtotal = day_of_week_price + first_class_charge
      first_class_summary = f"First Class Option: {first_class_yes_no}\n-adds ${first_class_charge:.2f}\n{'-'*27}\n"
    #################################
    #ADD ROW LOGIC###################
    elif is_leg_room_row:
      additional_charges = leg_room_charge
      subtotal = day_of_week_price + leg_room_charge
      premium_charge_summary = f"Premium Row Charges: {premium_seating_yes_no}\n-adds ${additional_charges:.2f}\n{'-'*27}\n"
    elif is_exit_row:
      additional_charges = exit_row_charge
      subtotal = day_of_week_price + exit_row_charge
      premium_charge_summary = f"Premium Row Charges: {premium_seating_yes_no}\n-adds ${additional_charges:.2f}\n{'-'*27}\n"
    else:
      additional_charges = additional_charges
      subtotal = day_of_week_price
    #BAGGAGE COSTS###################
    if baggage_pricing(number_of_bags) == 0: #<-- BAG COST FUNCTION
      baggage_summary = ''
    elif baggage_pricing(number_of_bags) > 0: #<-- BAG COST FUNCTION
      baggage_summary = f"""Baggage costs: ${baggage_pricing(number_of_bags):.2f}\n""" #<-- BAG COST FUNCTION
    #################################
    #TOTAL & PRINT###################
    tax = subtotal * 0.18
    total = subtotal + tax + baggage_pricing(number_of_bags) #<-- BAG COST FUNCTION
    summary = f"""\n{'*'*27}\nTICKET PRICE SUMMARY:\n\n{'-'*27}\nFare: ${day_of_week_price:.2f}\n{'-'*27}\n{first_class_summary}{premium_charge_summary}\n{'*'*18}\nSubtotal: ${subtotal:.2f}\nTaxes: ${tax:.2f}\n{baggage_summary}\nTOTAL: ${total:.2f}\n{'*'*27}"""

#SECOND IF
  elif destination == 'LAX':
    day_of_week_price = lax_pricing(day) #<-- LAX FUNCTION
    #CHECK FIRST CLASS###############
    if is_first_class:
      first_class_charge = day_of_week_price * 0.75
      subtotal = day_of_week_price + first_class_charge
      first_class_summary = f"First Class Option: {first_class_yes_no}\n-adds ${first_class_charge:.2f}\n{'-'*27}\n"
    #################################
    #ADD ROW LOGIC###################
    elif is_leg_room_row:
      additional_charges = leg_room_charge
      subtotal = day_of_week_price + leg_room_charge
      premium_charge_summary = f"Premium Row Charges: {premium_seating_yes_no}\n-adds ${additional_charges:.2f}\n{'-'*27}\n"
    elif is_exit_row:
      additional_charges = exit_row_charge
      subtotal = day_of_week_price + exit_row_charge
      premium_charge_summary = f"Premium Row Charges: {premium_seating_yes_no}\n-adds ${additional_charges:.2f}\n{'-'*27}\n"
    else:
      additional_charges = additional_charges
      subtotal = day_of_week_price
    #BAGGAGE COSTS###################
    if baggage_pricing(number_of_bags) == 0: #<-- BAG COST FUNCTION
      baggage_summary = ''
    elif baggage_pricing(number_of_bags) > 0: #<-- BAG COST FUNCTION
      baggage_summary = f"""Baggage costs: ${baggage_pricing(number_of_bags):.2f}\n""" #<-- BAG COST FUNCTION
    #################################
    #TOTAL & PRINT###################
    tax = subtotal * 0.18
    total = subtotal + tax + baggage_pricing(number_of_bags) #<-- BAG COST FUNCTION
    summary = f"""\n{'*'*27}\nTICKET PRICE SUMMARY:\n\n{'-'*27}\nFare: ${day_of_week_price:.2f}\n{'-'*27}\n{first_class_summary}{premium_charge_summary}\n{'*'*18}\nSubtotal: ${subtotal:.2f}\nTaxes: ${tax:.2f}\n{baggage_summary}\nTOTAL: ${total:.2f}\n{'*'*27}"""

#THIRD IF
  elif destination == 'MIA':
    day_of_week_price = mia_pricing(day) #<-- MIA FUNCTION
    #CHECK FIRST CLASS###############
    if is_first_class:
      first_class_charge = day_of_week_price * 0.75
      subtotal = day_of_week_price + first_class_charge
      first_class_summary = f"First Class Option: {first_class_yes_no}\n-adds ${first_class_charge:.2f}\n{'-'*27}\n"
    #################################
    #ADD ROW LOGIC###################
    elif is_leg_room_row:
      additional_charges = leg_room_charge
      subtotal = day_of_week_price + leg_room_charge
      premium_charge_summary = f"Premium Row Charges: {premium_seating_yes_no}\n-adds ${additional_charges:.2f}\n{'-'*27}\n"
    elif is_exit_row:
      additional_charges = exit_row_charge
      subtotal = day_of_week_price + exit_row_charge
      premium_charge_summary = f"Premium Row Charges: {premium_seating_yes_no}\n-adds ${additional_charges:.2f}\n{'-'*27}\n"
    else:
      additional_charges = additional_charges
      subtotal = day_of_week_price
    #BAGGAGE COSTS###################
    if baggage_pricing(number_of_bags) == 0: #<-- BAG COST FUNCTION
      baggage_summary = ''
    elif baggage_pricing(number_of_bags) > 0: #<-- BAG COST FUNCTION
      baggage_summary = f"""Baggage costs: ${baggage_pricing(number_of_bags):.2f}\n""" #<-- BAG COST FUNCTION
    #################################
    #TOTAL & PRINT###################
    tax = subtotal * 0.18
    total = subtotal + tax + baggage_pricing(number_of_bags) #<-- BAG COST FUNCTION
    summary = f"""\n{'*'*27}\nTICKET PRICE SUMMARY:\n\n{'-'*27}\nFare: ${day_of_week_price:.2f}\n{'-'*27}\n{first_class_summary}{premium_charge_summary}\n{'*'*18}\nSubtotal: ${subtotal:.2f}\nTaxes: ${tax:.2f}\n{baggage_summary}\nTOTAL: ${total:.2f}\n{'*'*27}"""

#FOURTH IF
  elif destination == 'SEA':
    day_of_week_price = sea_pricing(day) #<-- SEA FUNCTION
    #CHECK FIRST CLASS###############
    if is_first_class:
      first_class_charge = day_of_week_price * 0.75
      subtotal = day_of_week_price + first_class_charge
      first_class_summary = f"First Class Option: {first_class_yes_no}\n-adds ${first_class_charge:.2f}\n{'-'*27}\n"
    #################################
    #ADD ROW LOGIC###################
    elif is_leg_room_row:
      additional_charges = leg_room_charge
      subtotal = day_of_week_price + leg_room_charge
      premium_charge_summary = f"Premium Row Charges: {premium_seating_yes_no}\n-adds ${additional_charges:.2f}\n{'-'*27}\n"
    elif is_exit_row:
      additional_charges = exit_row_charge
      subtotal = day_of_week_price + exit_row_charge
      premium_charge_summary = f"Premium Row Charges: {premium_seating_yes_no}\n-adds ${additional_charges:.2f}\n{'-'*27}\n"
    else:
      additional_charges = additional_charges
      subtotal = day_of_week_price
    #BAGGAGE COSTS###################
    if baggage_pricing(number_of_bags) == 0: #<-- BAG COST FUNCTION
      baggage_summary = ''
    elif baggage_pricing(number_of_bags) > 0: #<-- BAG COST FUNCTION
      baggage_summary = f"""Baggage costs: ${baggage_pricing(number_of_bags):.2f}\n""" #<-- BAG COST FUNCTION
    #################################
    #TOTAL & PRINT###################
    tax = subtotal * 0.18
    total = subtotal + tax + baggage_pricing(number_of_bags) #<-- BAG COST FUNCTION
    summary = f"""\n{'*'*27}\nTICKET PRICE SUMMARY:\n\n{'-'*27}\nFare: ${day_of_week_price:.2f}\n{'-'*27}\n{first_class_summary}{premium_charge_summary}\n{'*'*18}\nSubtotal: ${subtotal:.2f}\nTaxes: ${tax:.2f}\n{baggage_summary}\nTOTAL: ${total:.2f}\n{'*'*27}"""

#FINAL ELIF
  elif destination == 'BOS':
    day_of_week_price = bos_pricing(day) #<-- BOS FUNCTION
    #CHECK FIRST CLASS###############
    if is_first_class:
      first_class_charge = day_of_week_price * 0.75
      subtotal = day_of_week_price + first_class_charge
      first_class_summary = f"First Class Option: {first_class_yes_no}\n-adds ${first_class_charge:.2f}\n{'-'*27}\n"
    #################################
    #ADD ROW LOGIC###################
    elif is_leg_room_row:
      additional_charges = leg_room_charge
      subtotal = day_of_week_price + leg_room_charge
      premium_charge_summary = f"Premium Row Charges: {premium_seating_yes_no}\n-adds ${additional_charges:.2f}\n{'-'*27}\n"
    elif is_exit_row:
      additional_charges = exit_row_charge
      subtotal = day_of_week_price + exit_row_charge
      premium_charge_summary = f"Premium Row Charges: {premium_seating_yes_no}\n-adds ${additional_charges:.2f}\n{'-'*27}\n"
    else:
      additional_charges = additional_charges
      subtotal = day_of_week_price
    #BAGGAGE COSTS###################
    if baggage_pricing(number_of_bags) == 0: #<-- BAG COST FUNCTION
      baggage_summary = ''
    elif baggage_pricing(number_of_bags) > 0: #<-- BAG COST FUNCTION
      baggage_summary = f"""Baggage costs: ${baggage_pricing(number_of_bags):.2f}\n""" #<-- BAG COST FUNCTION
    #################################
    #TOTAL & PRINT###################
    tax = subtotal * 0.18
    total = subtotal + tax + baggage_pricing(number_of_bags) #<-- BAG COST FUNCTION
    summary = f"""\n{'*'*27}\nTICKET PRICE SUMMARY:\n\n{'-'*27}\nFare: ${day_of_week_price:.2f}\n{'-'*27}\n{first_class_summary}{premium_charge_summary}\n{'*'*18}\nSubtotal: ${subtotal:.2f}\nTaxes: ${tax:.2f}\n{baggage_summary}\nTOTAL: ${total:.2f}\n{'*'*27}"""

#END IF - NO ELSE
  return summary


#######################################################
print("---Enter Information---\n")
destination = input("Destination Options:\nDFW LAX MIA SEA BOS --> ").upper()
day = input("\nDay of week:\nMON TUE WED THU FRI SAT SUN --> ").upper()
print("\nDesired Seating:\n-First Class (Rows 1-7) + 75%\n-Exit Row (Rows 14-15) + $49\n-Premium Seating: (Rows 8-13, 16,20) + $35\n-No Charge: (Rows 21-35)")
row = input("\nDesired Row Number: ")
number_of_bags = input("\nBaggage:\n-First carry-on + $35\n-Additional carry-on + $25\n\nNumber of carry-on bags: ")


if (destination not in ['DFW', 'LAX', 'MIA', 'SEA', 'BOS']) or (day not in ['MON', 'TUE', 'WED', 'THU', 'FRI', 'SAT', 'SUN']) or (not row.isdigit()) or (not number_of_bags.isdigit()):
  print("\nERROR:\nWrong input type for one or multiple choices.")
else:
  number_of_bags = int(float(number_of_bags))
  row = int(float(row))
  print(fare_calculation(destination, day, row, number_of_bags))

# %% [markdown]
# # [✅] Phase 6 Premium Plus

# %%
##### TODO - Phase 6 Premium Plus
#
# [✅] add option in inputs
# [✅] change baggage function to check for premium plus and allow one free carr-on
# [✅] free preffered seating
#
# [✅] test a lot
#########################################################

#CALCULATES COSTS BY
  #DESTINATION
  #DAY
  #ROW
  #BAGGAGE
def fare_calculation(destination, day, row, number_of_bags, is_premium_plus):

  #MAIN FUNCTION VARIABLES
  fare = 0
  subtotal = 0
  tax = 0
  total = 0
  summary = ''

  #DETERMINE FIRST CLASS
  first_class_charge = 0
  first_class_yes_no = 'NO'
  is_first_class = False
  if 8>row>0:
    is_first_class = True
    first_class_yes_no = 'YES'
  first_class_summary = ''

  #DETERMINE ADDITIONAL CHARGES
  additional_charges = 0
  premium_seating_yes_no = 'NO'
  is_exit_row = False
  is_leg_room_row = False
  exit_row_charge = 49
  leg_room_charge = 35

  #PREMIUM PLUS DISCOUNT FOR PREMIUM SEATING
  if is_premium_plus:
    exit_row_charge = 0
    leg_room_charge = 0
  if 13<row<16:
    is_exit_row = True
    premium_seating_yes_no = 'YES'
  elif 7<row<14 or 15<row<21:
    is_leg_room_row = True
    premium_seating_yes_no = 'YES'
  premium_charge_summary = ''

  #DETERMINE BAGGAGE COSTS
  def baggage_pricing(number_of_bags):
    baggage_cost = 0
    if is_premium_plus:
        number_of_bags -= 1
    if number_of_bags == 1:
      baggage_cost = 35
    elif number_of_bags > 1:
      baggage_cost = ((number_of_bags-1) * 25)+35

    return baggage_cost
  baggage_summary = ''

  #DFW PRICING BY DAY
  def dfw_pricing(day):
    fare = 0
    if day == 'MON':
      fare = 213
    elif day == 'TUE':
      fare = 198
    elif day == 'WED':
      fare = 198
    elif day == 'THU':
      fare = 213
    elif day == 'FRI':
      fare = 399
    elif day == 'SAT':
      fare = 213
    elif day == 'SUN':
      fare = 198
    return fare

  #LAX PRICING BY DAY
  def lax_pricing(day):
    fare = 0
    if day == 'MON':
      fare = 334
    elif day == 'TUE':
      fare = 314
    elif day == 'WED':
      fare = 314
    elif day == 'THU':
      fare = 334
    elif day == 'FRI':
      fare = 429
    elif day == 'SAT':
      fare = 334
    elif day == 'SUN':
      fare = 314
    return fare

  #MIA PRICING BY DAY
  def mia_pricing(day):
    fare = 0
    if day == 'MON':
      fare = 279
    elif day == 'TUE':
      fare = 204
    elif day == 'WED':
      fare = 204
    elif day == 'THU':
      fare = 279
    elif day == 'FRI':
      fare = 370
    elif day == 'SAT':
      fare = 279
    elif day == 'SUN':
      fare = 204
    return fare

  #SEA PRICING BY DAY
  def sea_pricing(day):
    fare = 0
    if day == 'MON':
      fare = 315
    elif day == 'TUE':
      fare = 294
    elif day == 'WED':
      fare = 294
    elif day == 'THU':
      fare = 315
    elif day == 'FRI':
      fare = 430
    elif day == 'SAT':
      fare = 315
    elif day == 'SUN':
      fare = 294
    return fare

  #BOS PRICING BY DAY
  def bos_pricing(day):
    fare = 0
    if day == 'MON':
      fare = 241
    elif day == 'TUE':
      fare = 205
    elif day == 'WED':
      fare = 205
    elif day == 'THU':
      fare = 241
    elif day == 'FRI':
      fare = 298
    elif day == 'SAT':
      fare = 241
    elif day == 'SUN':
      fare = 205
    return fare

  #CHECK FOR DESTINATION & FIRST_CLASS & ROW CHARGES --> USES FUNCTIONS ABOVE <--
#START IF
  if destination == 'DFW':
    day_of_week_price = dfw_pricing(day) #<-- DFW FUNCTION
    #CHECK FIRST CLASS###############
    if is_first_class:
      first_class_charge = day_of_week_price * 0.75
      subtotal = day_of_week_price + first_class_charge
      first_class_summary = f"First Class Option: {first_class_yes_no}\n-adds ${first_class_charge:.2f}\n{'-'*27}\n"
    #ADD ROW LOGIC###################
    elif is_leg_room_row:
      if is_premium_plus:
        subtotal = day_of_week_price
        premium_charge_summary = ''
      else:
        premium_charge_summary = f"Premium Row Charges: {premium_seating_yes_no}\n-adds ${leg_room_charge:.2f}\n{'-'*27}\n"
        subtotal = day_of_week_price + leg_room_charge
    elif is_exit_row:
      if is_premium_plus:
        subtotal = day_of_week_price
        premium_charge_summary = ''
      else:
        premium_charge_summary = f"Premium Row Charges: {premium_seating_yes_no}\n-adds ${exit_row_charge:.2f}\n{'-'*27}\n"
        subtotal = day_of_week_price + exit_row_charge
    else:
      subtotal = day_of_week_price
    #BAGGAGE COSTS###################
    if baggage_pricing(number_of_bags) == 0:
      baggage_summary = ''
    elif baggage_pricing(number_of_bags) > 0:
      if is_premium_plus:
        baggage_summary = f"""Baggage costs: ${(baggage_pricing(number_of_bags)):.2f}\n"""
      else:
        baggage_summary = f"""Baggage costs: ${baggage_pricing(number_of_bags):.2f}\n"""
    #################################
    #TOTAL & PRINT##################
    if is_premium_plus:
      tax = (subtotal + 94) * 0.18
      total = (subtotal+94) + tax + baggage_pricing(number_of_bags)
    else:
      tax = subtotal * 0.18
      total = subtotal + tax + baggage_pricing(number_of_bags)
    summary = f"""\n{'*'*27}\nTICKET PRICE SUMMARY:\n\n{'-'*27}\nFare: ${day_of_week_price:.2f}\n{'-'*27}\n{first_class_summary}{premium_charge_summary}\n{'*'*18}\nSubtotal: ${subtotal:.2f}\nPremium: $94\nTaxes: ${tax:.2f}\n{baggage_summary}\nTOTAL: ${total:.2f}\n{'*'*27}"""

#SECOND IF
  elif destination == 'LAX':
    day_of_week_price = lax_pricing(day) #<-- LAX FUNCTION
    #CHECK FIRST CLASS###############
    if is_first_class:
      first_class_charge = day_of_week_price * 0.75
      subtotal = day_of_week_price + first_class_charge
      first_class_summary = f"First Class Option: {first_class_yes_no}\n-adds ${first_class_charge:.2f}\n{'-'*27}\n"
    #ADD ROW LOGIC###################
    elif is_leg_room_row:
      if is_premium_plus:
        subtotal = day_of_week_price
        premium_charge_summary = ''
      else:
        premium_charge_summary = f"Premium Row Charges: {premium_seating_yes_no}\n-adds ${leg_room_charge:.2f}\n{'-'*27}\n"
        subtotal = day_of_week_price + leg_room_charge
    elif is_exit_row:
      if is_premium_plus:
        subtotal = day_of_week_price
        premium_charge_summary = ''
      else:
        premium_charge_summary = f"Premium Row Charges: {premium_seating_yes_no}\n-adds ${exit_row_charge:.2f}\n{'-'*27}\n"
        subtotal = day_of_week_price + exit_row_charge
    else:
      subtotal = day_of_week_price
    #BAGGAGE COSTS###################
    if baggage_pricing(number_of_bags) == 0:
      baggage_summary = ''
    elif baggage_pricing(number_of_bags) > 0:
      if is_premium_plus:
        baggage_summary = f"""Baggage costs: ${(baggage_pricing(number_of_bags)):.2f}\n"""
      else:
        baggage_summary = f"""Baggage costs: ${baggage_pricing(number_of_bags):.2f}\n"""
    #################################
    #TOTAL & PRINT##################
    if is_premium_plus:
      tax = (subtotal + 94) * 0.18
      total = (subtotal+94) + tax + baggage_pricing(number_of_bags)
    else:
      tax = subtotal * 0.18
      total = subtotal + tax + baggage_pricing(number_of_bags)
    summary = f"""\n{'*'*27}\nTICKET PRICE SUMMARY:\n\n{'-'*27}\nFare: ${day_of_week_price:.2f}\n{'-'*27}\n{first_class_summary}{premium_charge_summary}\n{'*'*18}\nSubtotal: ${subtotal:.2f}\nPremium: $94\nTaxes: ${tax:.2f}\n{baggage_summary}\nTOTAL: ${total:.2f}\n{'*'*27}"""

#THIRD IF
  elif destination == 'MIA':
    day_of_week_price = mia_pricing(day) #<-- MIA FUNCTION
    #CHECK FIRST CLASS###############
    if is_first_class:
      first_class_charge = day_of_week_price * 0.75
      subtotal = day_of_week_price + first_class_charge
      first_class_summary = f"First Class Option: {first_class_yes_no}\n-adds ${first_class_charge:.2f}\n{'-'*27}\n"
    #ADD ROW LOGIC###################
    elif is_leg_room_row:
      if is_premium_plus:
        subtotal = day_of_week_price
        premium_charge_summary = ''
      else:
        premium_charge_summary = f"Premium Row Charges: {premium_seating_yes_no}\n-adds ${leg_room_charge:.2f}\n{'-'*27}\n"
        subtotal = day_of_week_price + leg_room_charge
    elif is_exit_row:
      if is_premium_plus:
        subtotal = day_of_week_price
        premium_charge_summary = ''
      else:
        premium_charge_summary = f"Premium Row Charges: {premium_seating_yes_no}\n-adds ${exit_row_charge:.2f}\n{'-'*27}\n"
        subtotal = day_of_week_price + exit_row_charge
    else:
      subtotal = day_of_week_price
    #BAGGAGE COSTS###################
    if baggage_pricing(number_of_bags) == 0:
      baggage_summary = ''
    elif baggage_pricing(number_of_bags) > 0:
      if is_premium_plus:
        baggage_summary = f"""Baggage costs: ${(baggage_pricing(number_of_bags)):.2f}\n"""
      else:
        baggage_summary = f"""Baggage costs: ${baggage_pricing(number_of_bags):.2f}\n"""
    #################################
    #TOTAL & PRINT##################
    if is_premium_plus:
      tax = (subtotal + 94) * 0.18
      total = (subtotal+94) + tax + baggage_pricing(number_of_bags)
    else:
      tax = subtotal * 0.18
      total = subtotal + tax + baggage_pricing(number_of_bags)
    summary = f"""\n{'*'*27}\nTICKET PRICE SUMMARY:\n\n{'-'*27}\nFare: ${day_of_week_price:.2f}\n{'-'*27}\n{first_class_summary}{premium_charge_summary}\n{'*'*18}\nSubtotal: ${subtotal:.2f}\nPremium: $94\nTaxes: ${tax:.2f}\n{baggage_summary}\nTOTAL: ${total:.2f}\n{'*'*27}"""

#FOURTH IF
  elif destination == 'SEA':
    day_of_week_price = sea_pricing(day) #<-- SEA FUNCTION
    #CHECK FIRST CLASS###############
    if is_first_class:
      first_class_charge = day_of_week_price * 0.75
      subtotal = day_of_week_price + first_class_charge
      first_class_summary = f"First Class Option: {first_class_yes_no}\n-adds ${first_class_charge:.2f}\n{'-'*27}\n"
    #ADD ROW LOGIC###################
    elif is_leg_room_row:
      if is_premium_plus:
        subtotal = day_of_week_price
        premium_charge_summary = ''
      else:
        premium_charge_summary = f"Premium Row Charges: {premium_seating_yes_no}\n-adds ${leg_room_charge:.2f}\n{'-'*27}\n"
        subtotal = day_of_week_price + leg_room_charge
    elif is_exit_row:
      if is_premium_plus:
        subtotal = day_of_week_price
        premium_charge_summary = ''
      else:
        premium_charge_summary = f"Premium Row Charges: {premium_seating_yes_no}\n-adds ${exit_row_charge:.2f}\n{'-'*27}\n"
        subtotal = day_of_week_price + exit_row_charge
    else:
      subtotal = day_of_week_price
    #BAGGAGE COSTS###################
    if baggage_pricing(number_of_bags) == 0:
      baggage_summary = ''
    elif baggage_pricing(number_of_bags) > 0:
      if is_premium_plus:
        baggage_summary = f"""Baggage costs: ${(baggage_pricing(number_of_bags)):.2f}\n"""
      else:
        baggage_summary = f"""Baggage costs: ${baggage_pricing(number_of_bags):.2f}\n"""
    #################################
    #TOTAL & PRINT##################
    if is_premium_plus:
      tax = (subtotal + 94) * 0.18
      total = (subtotal+94) + tax + baggage_pricing(number_of_bags)
    else:
      tax = subtotal * 0.18
      total = subtotal + tax + baggage_pricing(number_of_bags)
    summary = f"""\n{'*'*27}\nTICKET PRICE SUMMARY:\n\n{'-'*27}\nFare: ${day_of_week_price:.2f}\n{'-'*27}\n{first_class_summary}{premium_charge_summary}\n{'*'*18}\nSubtotal: ${subtotal:.2f}\nPremium: $94\nTaxes: ${tax:.2f}\n{baggage_summary}\nTOTAL: ${total:.2f}\n{'*'*27}"""

#FINAL ELIF
  elif destination == 'BOS':
    day_of_week_price = bos_pricing(day) #<-- BOS FUNCTION
    #CHECK FIRST CLASS###############
    if is_first_class:
      first_class_charge = day_of_week_price * 0.75
      subtotal = day_of_week_price + first_class_charge
      first_class_summary = f"First Class Option: {first_class_yes_no}\n-adds ${first_class_charge:.2f}\n{'-'*27}\n"
    #ADD ROW LOGIC###################
    elif is_leg_room_row:
      if is_premium_plus:
        subtotal = day_of_week_price
        premium_charge_summary = ''
      else:
        premium_charge_summary = f"Premium Row Charges: {premium_seating_yes_no}\n-adds ${leg_room_charge:.2f}\n{'-'*27}\n"
        subtotal = day_of_week_price + leg_room_charge
    elif is_exit_row:
      if is_premium_plus:
        subtotal = day_of_week_price
        premium_charge_summary = ''
      else:
        premium_charge_summary = f"Premium Row Charges: {premium_seating_yes_no}\n-adds ${exit_row_charge:.2f}\n{'-'*27}\n"
        subtotal = day_of_week_price + exit_row_charge
    else:
      subtotal = day_of_week_price
    #BAGGAGE COSTS###################
    if baggage_pricing(number_of_bags) == 0:
      baggage_summary = ''
    elif baggage_pricing(number_of_bags) > 0:
      if is_premium_plus:
        baggage_summary = f"""Baggage costs: ${(baggage_pricing(number_of_bags)):.2f}\n"""
      else:
        baggage_summary = f"""Baggage costs: ${baggage_pricing(number_of_bags):.2f}\n"""
    #################################
    #TOTAL & PRINT##################
    if is_premium_plus:
      tax = (subtotal + 94) * 0.18
      total = (subtotal+94) + tax + baggage_pricing(number_of_bags)
    else:
      tax = subtotal * 0.18
      total = subtotal + tax + baggage_pricing(number_of_bags)
    summary = f"""\n{'*'*27}\nTICKET PRICE SUMMARY:\n\n{'-'*27}\nFare: ${day_of_week_price:.2f}\n{'-'*27}\n{first_class_summary}{premium_charge_summary}\n{'*'*18}\nSubtotal: ${subtotal:.2f}\nPremium: $94\nTaxes: ${tax:.2f}\n{baggage_summary}\nTOTAL: ${total:.2f}\n{'*'*27}"""

#END IF - NO ELSE
  return summary


#######################################################
print("---Enter Information---\n")
destination = input("Destination Options:\nDFW LAX MIA SEA BOS --> ").upper()
day = input("\nDay of week:\nMON TUE WED THU FRI SAT SUN --> ").upper()
row = input("\nDesired Row Number: ")
#PREMIUM PLUS##############
number_of_bags = input("\nBaggage:\n-First carry-on + $35(free for Premium Plus)\n-Additional carry-on + $25\n\nNumber of carry-on bags: ")
premium_plus_ticket = input("\nAdd Premium-Plus for $94:\n-no change fee\n-one free checked bag\n-FREE Premium seating\n\n(y/n): \n").upper()
is_premium_plus = False
premium_plus_intro = ''
is_not_premium_plus_cost = ' + $35'
if 'Y' in premium_plus_ticket:
  is_premium_plus = True
  is_not_premium_plus_cost = ''
  premium_plus_intro = f"\nPremium Plus members:\n"
###########################
print(f"\nDesired Seating:\n-First Class (Rows 1-7) + 75%\n-Exit Row (Rows 14-15) + $49\n-Premium Seating: (Rows 8-13, 16,20){is_not_premium_plus_cost}\n-No Charge: (Rows 21-35)")

if (destination not in ['DFW', 'LAX', 'MIA', 'SEA', 'BOS']) or (day not in ['MON', 'TUE', 'WED', 'THU', 'FRI', 'SAT', 'SUN']) or (not row.isdigit()) or (int(row) == 0) or (not number_of_bags.isdigit()) or (premium_plus_ticket not in ['Y', 'N']):
  print("\nERROR:\nWrong input type for one or multiple choices.")
else:
  number_of_bags = int(float(number_of_bags))
  row = int(float(row))
  print(fare_calculation(destination, day, row, number_of_bags, is_premium_plus))
# Out:
# ---Enter Information---
#
# Destination Options:
# DFW LAX MIA SEA BOS --> bos
#
# Day of week:
# MON TUE WED THU FRI SAT SUN --> mon
#
# Desired Row Number: 15
#
# Baggage:
# -First carry-on + $35(free for Premium Plus)
# -Additional carry-on + $25
#
# Number of carry-on bags: 2
#
# Add Premium-Plus for $94:
# -no change fee
# -one free checked bag
# -FREE Premium seating
#
# (y/n):
# y
#
# Desired Seating:
# -First Class (Rows 1-7) + 75%
# -Exit Row (Rows 14-15) + $49
# -Premium Seating: (Rows 8-13, 16,20)
# -No Charge: (Rows 21-35)
#
# ***************************
# TICKET PRICE SUMMARY:
#
# ---------------------------
# Fare: $241.00
# ---------------------------
#
# ******************
# Subtotal: $241.00
# Premium: $94
# Taxes: $60.30
# Baggage costs: $60.00
#
# TOTAL: $455.30
# ***************************

# %% [markdown]
# # [✅] Phase 7 Check for Errors

# %%
##### TODO - Phase 7 Checking For Errors
#
# CHECK FOR ERRORS:
# -[✅] incorrect row
# -[✅] destination MUST be 1of5 cities
# -[✅] day must be mon-sun
#
#########################################################

#CALCULATES COSTS BY
  #DESTINATION
  #DAY
  #ROW
  #BAGGAGE
def fare_calculation(destination, day, row, number_of_bags, is_premium_plus):

  #MAIN FUNCTION VARIABLES
  fare = 0
  subtotal = 0
  tax = 0
  total = 0
  summary = ''

  #DETERMINE FIRST CLASS
  first_class_charge = 0
  first_class_yes_no = 'NO'
  is_first_class = False
  if 8>row>0:
    is_first_class = True
    first_class_yes_no = 'YES'
  first_class_summary = ''

  #DETERMINE ADDITIONAL CHARGES
  additional_charges = 0
  premium_seating_yes_no = 'NO'
  is_exit_row = False
  is_leg_room_row = False
  exit_row_charge = 49
  leg_room_charge = 35

  #PREMIUM PLUS DISCOUNT FOR PREMIUM SEATING
  if is_premium_plus:
    exit_row_charge = 0
    leg_room_charge = 0
  if 13<row<16:
    is_exit_row = True
    premium_seating_yes_no = 'YES'
  elif 7<row<14 or 15<row<21:
    is_leg_room_row = True
    premium_seating_yes_no = 'YES'
  premium_charge_summary = ''

  #DETERMINE BAGGAGE COSTS
  def baggage_pricing(number_of_bags):
    baggage_cost = 0
    if is_premium_plus:
        number_of_bags -= 1
    if number_of_bags == 1:
      baggage_cost = 35
    elif number_of_bags > 1:
      baggage_cost = ((number_of_bags-1) * 25)+35

    return baggage_cost
  baggage_summary = ''

  #DFW PRICING BY DAY
  def dfw_pricing(day):
    fare = 0
    if day == 'MON':
      fare = 213
    elif day == 'TUE':
      fare = 198
    elif day == 'WED':
      fare = 198
    elif day == 'THU':
      fare = 213
    elif day == 'FRI':
      fare = 399
    elif day == 'SAT':
      fare = 213
    elif day == 'SUN':
      fare = 198
    return fare

  #LAX PRICING BY DAY
  def lax_pricing(day):
    fare = 0
    if day == 'MON':
      fare = 334
    elif day == 'TUE':
      fare = 314
    elif day == 'WED':
      fare = 314
    elif day == 'THU':
      fare = 334
    elif day == 'FRI':
      fare = 429
    elif day == 'SAT':
      fare = 334
    elif day == 'SUN':
      fare = 314
    return fare

  #MIA PRICING BY DAY
  def mia_pricing(day):
    fare = 0
    if day == 'MON':
      fare = 279
    elif day == 'TUE':
      fare = 204
    elif day == 'WED':
      fare = 204
    elif day == 'THU':
      fare = 279
    elif day == 'FRI':
      fare = 370
    elif day == 'SAT':
      fare = 279
    elif day == 'SUN':
      fare = 204
    return fare

  #SEA PRICING BY DAY
  def sea_pricing(day):
    fare = 0
    if day == 'MON':
      fare = 315
    elif day == 'TUE':
      fare = 294
    elif day == 'WED':
      fare = 294
    elif day == 'THU':
      fare = 315
    elif day == 'FRI':
      fare = 430
    elif day == 'SAT':
      fare = 315
    elif day == 'SUN':
      fare = 294
    return fare

  #BOS PRICING BY DAY
  def bos_pricing(day):
    fare = 0
    if day == 'MON':
      fare = 241
    elif day == 'TUE':
      fare = 205
    elif day == 'WED':
      fare = 205
    elif day == 'THU':
      fare = 241
    elif day == 'FRI':
      fare = 298
    elif day == 'SAT':
      fare = 241
    elif day == 'SUN':
      fare = 205
    return fare

  #CHECK FOR DESTINATION & FIRST_CLASS & ROW CHARGES --> USES FUNCTIONS ABOVE <--
#START IF
  if destination == 'DFW':
    day_of_week_price = dfw_pricing(day) #<-- DFW FUNCTION
    #CHECK FIRST CLASS###############
    if is_first_class:
      first_class_charge = day_of_week_price * 0.75
      subtotal = day_of_week_price + first_class_charge
      first_class_summary = f"First Class Option: {first_class_yes_no}\n-adds ${first_class_charge:.2f}\n{'-'*27}\n"
    #ADD ROW LOGIC###################
    elif is_leg_room_row:
      if is_premium_plus:
        subtotal = day_of_week_price
        premium_charge_summary = ''
      else:
        premium_charge_summary = f"Premium Row Charges: {premium_seating_yes_no}\n-adds ${leg_room_charge:.2f}\n{'-'*27}\n"
        subtotal = day_of_week_price + leg_room_charge
    elif is_exit_row:
      if is_premium_plus:
        subtotal = day_of_week_price
        premium_charge_summary = ''
      else:
        premium_charge_summary = f"Premium Row Charges: {premium_seating_yes_no}\n-adds ${exit_row_charge:.2f}\n{'-'*27}\n"
        subtotal = day_of_week_price + exit_row_charge
    else:
      subtotal = day_of_week_price
    #BAGGAGE COSTS###################
    if baggage_pricing(number_of_bags) == 0:
      baggage_summary = ''
    elif baggage_pricing(number_of_bags) > 0:
      if is_premium_plus:
        baggage_summary = f"""Baggage costs: ${(baggage_pricing(number_of_bags)):.2f}\n"""
      else:
        baggage_summary = f"""Baggage costs: ${baggage_pricing(number_of_bags):.2f}\n"""
    #################################
    #TOTAL & PRINT##################
    if is_premium_plus:
      tax = (subtotal + 94) * 0.18
      total = (subtotal+94) + tax + baggage_pricing(number_of_bags)
    else:
      tax = subtotal * 0.18
      total = subtotal + tax + baggage_pricing(number_of_bags)
    summary = f"""\n{'*'*27}\nTICKET PRICE SUMMARY:\n\n{'-'*27}\nFare: ${day_of_week_price:.2f}\n{'-'*27}\n{first_class_summary}{premium_charge_summary}\n{'*'*18}\nSubtotal: ${subtotal:.2f}\nPremium: $94\nTaxes: ${tax:.2f}\n{baggage_summary}\nTOTAL: ${total:.2f}\n{'*'*27}"""

#SECOND IF
  elif destination == 'LAX':
    day_of_week_price = lax_pricing(day) #<-- LAX FUNCTION
    #CHECK FIRST CLASS###############
    if is_first_class:
      first_class_charge = day_of_week_price * 0.75
      subtotal = day_of_week_price + first_class_charge
      first_class_summary = f"First Class Option: {first_class_yes_no}\n-adds ${first_class_charge:.2f}\n{'-'*27}\n"
    #ADD ROW LOGIC###################
    elif is_leg_room_row:
      if is_premium_plus:
        subtotal = day_of_week_price
        premium_charge_summary = ''
      else:
        premium_charge_summary = f"Premium Row Charges: {premium_seating_yes_no}\n-adds ${leg_room_charge:.2f}\n{'-'*27}\n"
        subtotal = day_of_week_price + leg_room_charge
    elif is_exit_row:
      if is_premium_plus:
        subtotal = day_of_week_price
        premium_charge_summary = ''
      else:
        premium_charge_summary = f"Premium Row Charges: {premium_seating_yes_no}\n-adds ${exit_row_charge:.2f}\n{'-'*27}\n"
        subtotal = day_of_week_price + exit_row_charge
    else:
      subtotal = day_of_week_price
    #BAGGAGE COSTS###################
    if baggage_pricing(number_of_bags) == 0:
      baggage_summary = ''
    elif baggage_pricing(number_of_bags) > 0:
      if is_premium_plus:
        baggage_summary = f"""Baggage costs: ${(baggage_pricing(number_of_bags)):.2f}\n"""
      else:
        baggage_summary = f"""Baggage costs: ${baggage_pricing(number_of_bags):.2f}\n"""
    #################################
    #TOTAL & PRINT##################
    if is_premium_plus:
      tax = (subtotal + 94) * 0.18
      total = (subtotal+94) + tax + baggage_pricing(number_of_bags)
    else:
      tax = subtotal * 0.18
      total = subtotal + tax + baggage_pricing(number_of_bags)
    summary = f"""\n{'*'*27}\nTICKET PRICE SUMMARY:\n\n{'-'*27}\nFare: ${day_of_week_price:.2f}\n{'-'*27}\n{first_class_summary}{premium_charge_summary}\n{'*'*18}\nSubtotal: ${subtotal:.2f}\nPremium: $94\nTaxes: ${tax:.2f}\n{baggage_summary}\nTOTAL: ${total:.2f}\n{'*'*27}"""

#THIRD IF
  elif destination == 'MIA':
    day_of_week_price = mia_pricing(day) #<-- MIA FUNCTION
    #CHECK FIRST CLASS###############
    if is_first_class:
      first_class_charge = day_of_week_price * 0.75
      subtotal = day_of_week_price + first_class_charge
      first_class_summary = f"First Class Option: {first_class_yes_no}\n-adds ${first_class_charge:.2f}\n{'-'*27}\n"
    #ADD ROW LOGIC###################
    elif is_leg_room_row:
      if is_premium_plus:
        subtotal = day_of_week_price
        premium_charge_summary = ''
      else:
        premium_charge_summary = f"Premium Row Charges: {premium_seating_yes_no}\n-adds ${leg_room_charge:.2f}\n{'-'*27}\n"
        subtotal = day_of_week_price + leg_room_charge
    elif is_exit_row:
      if is_premium_plus:
        subtotal = day_of_week_price
        premium_charge_summary = ''
      else:
        premium_charge_summary = f"Premium Row Charges: {premium_seating_yes_no}\n-adds ${exit_row_charge:.2f}\n{'-'*27}\n"
        subtotal = day_of_week_price + exit_row_charge
    else:
      subtotal = day_of_week_price
    #BAGGAGE COSTS###################
    if baggage_pricing(number_of_bags) == 0:
      baggage_summary = ''
    elif baggage_pricing(number_of_bags) > 0:
      if is_premium_plus:
        baggage_summary = f"""Baggage costs: ${(baggage_pricing(number_of_bags)):.2f}\n"""
      else:
        baggage_summary = f"""Baggage costs: ${baggage_pricing(number_of_bags):.2f}\n"""
    #################################
    #TOTAL & PRINT##################
    if is_premium_plus:
      tax = (subtotal + 94) * 0.18
      total = (subtotal+94) + tax + baggage_pricing(number_of_bags)
    else:
      tax = subtotal * 0.18
      total = subtotal + tax + baggage_pricing(number_of_bags)
    summary = f"""\n{'*'*27}\nTICKET PRICE SUMMARY:\n\n{'-'*27}\nFare: ${day_of_week_price:.2f}\n{'-'*27}\n{first_class_summary}{premium_charge_summary}\n{'*'*18}\nSubtotal: ${subtotal:.2f}\nPremium: $94\nTaxes: ${tax:.2f}\n{baggage_summary}\nTOTAL: ${total:.2f}\n{'*'*27}"""

#FOURTH IF
  elif destination == 'SEA':
    day_of_week_price = sea_pricing(day) #<-- SEA FUNCTION
    #CHECK FIRST CLASS###############
    if is_first_class:
      first_class_charge = day_of_week_price * 0.75
      subtotal = day_of_week_price + first_class_charge
      first_class_summary = f"First Class Option: {first_class_yes_no}\n-adds ${first_class_charge:.2f}\n{'-'*27}\n"
    #ADD ROW LOGIC###################
    elif is_leg_room_row:
      if is_premium_plus:
        subtotal = day_of_week_price
        premium_charge_summary = ''
      else:
        premium_charge_summary = f"Premium Row Charges: {premium_seating_yes_no}\n-adds ${leg_room_charge:.2f}\n{'-'*27}\n"
        subtotal = day_of_week_price + leg_room_charge
    elif is_exit_row:
      if is_premium_plus:
        subtotal = day_of_week_price
        premium_charge_summary = ''
      else:
        premium_charge_summary = f"Premium Row Charges: {premium_seating_yes_no}\n-adds ${exit_row_charge:.2f}\n{'-'*27}\n"
        subtotal = day_of_week_price + exit_row_charge
    else:
      subtotal = day_of_week_price
    #BAGGAGE COSTS###################
    if baggage_pricing(number_of_bags) == 0:
      baggage_summary = ''
    elif baggage_pricing(number_of_bags) > 0:
      if is_premium_plus:
        baggage_summary = f"""Baggage costs: ${(baggage_pricing(number_of_bags)):.2f}\n"""
      else:
        baggage_summary = f"""Baggage costs: ${baggage_pricing(number_of_bags):.2f}\n"""
    #################################
    #TOTAL & PRINT##################
    if is_premium_plus:
      tax = (subtotal + 94) * 0.18
      total = (subtotal+94) + tax + baggage_pricing(number_of_bags)
    else:
      tax = subtotal * 0.18
      total = subtotal + tax + baggage_pricing(number_of_bags)
    summary = f"""\n{'*'*27}\nTICKET PRICE SUMMARY:\n\n{'-'*27}\nFare: ${day_of_week_price:.2f}\n{'-'*27}\n{first_class_summary}{premium_charge_summary}\n{'*'*18}\nSubtotal: ${subtotal:.2f}\nPremium: $94\nTaxes: ${tax:.2f}\n{baggage_summary}\nTOTAL: ${total:.2f}\n{'*'*27}"""

#FINAL ELIF
  elif destination == 'BOS':
    day_of_week_price = bos_pricing(day) #<-- BOS FUNCTION
    #CHECK FIRST CLASS###############
    if is_first_class:
      first_class_charge = day_of_week_price * 0.75
      subtotal = day_of_week_price + first_class_charge
      first_class_summary = f"First Class Option: {first_class_yes_no}\n-adds ${first_class_charge:.2f}\n{'-'*27}\n"
    #ADD ROW LOGIC###################
    elif is_leg_room_row:
      if is_premium_plus:
        subtotal = day_of_week_price
        premium_charge_summary = ''
      else:
        premium_charge_summary = f"Premium Row Charges: {premium_seating_yes_no}\n-adds ${leg_room_charge:.2f}\n{'-'*27}\n"
        subtotal = day_of_week_price + leg_room_charge
    elif is_exit_row:
      if is_premium_plus:
        subtotal = day_of_week_price
        premium_charge_summary = ''
      else:
        premium_charge_summary = f"Premium Row Charges: {premium_seating_yes_no}\n-adds ${exit_row_charge:.2f}\n{'-'*27}\n"
        subtotal = day_of_week_price + exit_row_charge
    else:
      subtotal = day_of_week_price
    #BAGGAGE COSTS###################
    if baggage_pricing(number_of_bags) == 0:
      baggage_summary = ''
    elif baggage_pricing(number_of_bags) > 0:
      if is_premium_plus:
        baggage_summary = f"""Baggage costs: ${(baggage_pricing(number_of_bags)):.2f}\n"""
      else:
        baggage_summary = f"""Baggage costs: ${baggage_pricing(number_of_bags):.2f}\n"""
    #################################
    #TOTAL & PRINT##################
    if is_premium_plus:
      tax = (subtotal + 94) * 0.18
      total = (subtotal+94) + tax + baggage_pricing(number_of_bags)
    else:
      tax = subtotal * 0.18
      total = subtotal + tax + baggage_pricing(number_of_bags)
    summary = f"""\n{'*'*27}\nTICKET PRICE SUMMARY:\n\n{'-'*27}\nFare: ${day_of_week_price:.2f}\n{'-'*27}\n{first_class_summary}{premium_charge_summary}\n{'*'*18}\nSubtotal: ${subtotal:.2f}\nPremium: $94\nTaxes: ${tax:.2f}\n{baggage_summary}\nTOTAL: ${total:.2f}\n{'*'*27}"""

#END IF - NO ELSE
  return summary


#######################################################
print("---Enter Information---\n")
destination = input("Destination Options:\nDFW LAX MIA SEA BOS --> ").upper()
day = input("\nDay of week:\nMON TUE WED THU FRI SAT SUN --> ").upper()
if day not in ['MON', 'TUE', 'WED', 'THU', 'FRI', 'SAT', 'SUN']:
  day = 'MON'
row = input("\nDesired Row Number: ")
#PREMIUM PLUS##############
number_of_bags = input("\nBaggage:\n-First carry-on + $35(free for Premium Plus)\n-Additional carry-on + $25\n\nNumber of carry-on bags: ")
premium_plus_ticket = input("\nAdd Premium-Plus for $94:\n-no change fee\n-one free checked bag\n-FREE Premium seating\n\n(y/n): \n").upper()
is_premium_plus = False
premium_plus_intro = ''
is_not_premium_plus_cost = ' + $35'
if 'Y' in premium_plus_ticket:
  is_premium_plus = True
  is_not_premium_plus_cost = ''
  premium_plus_intro = f"\nPremium Plus members:\n"
###########################
print(f"\nDesired Seating:\n-First Class (Rows 1-7) + 75%\n-Exit Row (Rows 14-15) + $49\n-Premium Seating: (Rows 8-13, 16,20){is_not_premium_plus_cost}\n-No Charge: (Rows 21-35)")

if (destination not in ['DFW', 'LAX', 'MIA', 'SEA', 'BOS']):
  print("\n--> Oops! Destination must be DFW, LAX, SEA, MIA or BOS.")
elif (not row.isdigit()) or (not (0<int(row)<36)):
  print("\n--> Oops! Row must be 1 - 35.")
elif (day not in ['MON', 'TUE', 'WED', 'THU', 'FRI', 'SAT', 'SUN']) or (not number_of_bags.isdigit()) or (premium_plus_ticket not in ['Y', 'N']):
  print("\nERROR:\nWrong input type for one or multiple choices.")
else:
  number_of_bags = int(float(number_of_bags))
  row = int(float(row))
  print(fare_calculation(destination, day, row, number_of_bags, is_premium_plus))
# Out:
# ---Enter Information---
#
# Destination Options:
# DFW LAX MIA SEA BOS --> bos
#
# Day of week:
# MON TUE WED THU FRI SAT SUN --> sun
#
# Desired Row Number: not
#
# Baggage:
# -First carry-on + $35(free for Premium Plus)
# -Additional carry-on + $25
#
# Number of carry-on bags: 2
#
# Add Premium-Plus for $94:
# -no change fee
# -one free checked bag
# -FREE Premium seating
#
# (y/n):
# y
#
# Desired Seating:
# -First Class (Rows 1-7) + 75%
# -Exit Row (Rows 14-15) + $49
# -Premium Seating: (Rows 8-13, 16,20)
# -No Charge: (Rows 21-35)
# Oops! Row must be 1 - 35.
